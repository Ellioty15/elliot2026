# %% [markdown]
# ---
# title: Trimester 1 Final Retrospective
# comments: true
# layout: post
# permalink: /trimester1final
# ---

# %% [markdown]
# # My Learning Progress
#
# # 1. Growth Throughout my Trimester
#
# ```mermaid
#
# graph TD
#
#     A[Start of Year] --> B[Focus Area: Organization]
#
#     B --> C[Improved task management through issues and kanban board]
#
#     C --> D[Communicated with my team members when to pull and organized our tasks]
#
#     A --> F[Focus Area: Initiative]
#
#     F --> G[Encouraging ideation]
#
#     G --> H[Leading module curriculum]
#
#     A --> J[Focus Area: Concept Development]
#
#     J --> K[Research & Learning]
#
#     K --> L[Refining Ideas]
#
#     L --> M[Implementing Concepts]
#
#     D --> S[End of Tri 1]
#
#     H --> S
#
#     M --> S
#
#     S --> T[Growth Achieved]
#
# ```
#
# # 2. Notable things I did this trimester
#
# ```mermaid
#
# timeline
#
#     title Notable things throughout this trimester
#
#     section Sprint 1
#
#         Creating Cool Documentation : Research mermaid
#
#                                     : Create helpful documentation
#
#     section Sprint 2
#
#         Java Team Teach : Ideate Lesson
#
#                            : Ensuring understanding of the lesson and creating homework
#
#     section Sprint 3
#
#         Lesson Creation : Adapt to Chromebook limitations
#
#                        : Develop curriculum
#
# ```
#
# # 3. Night at the Museum Experience
#
# ```mermaid
#
# mindmap
#
#   root((N@tM Experience))
#
#     Overall Experience
#
#       What went well
#
#       Challenges faced
#
#       Key takeaways
#
#     Favorite Comments
#
#       Mr: Mortensen - "Nobody reads text, it is more efficient to use diagrams"
#
#       George - "The Postman emulator is a cool way to show how API responses could look like"
#
#       Jennifer - "Although I'm not a computer person, these lessons help me understand the connection between fullstack and backend and what fullstack is"
#
# ```
# ![A quick selfie with Alex and Kush]({{site.baseurl}}/images/nightatthemuseumselfie.png)
#
# # 4. What do you want to do on the project, given more time?
#
# - I want to create an interactive table that will imitate an SQL database within the frontend.
#
# - For example, if I typed a table name with columns, and then added an entry, then it would show in the database.
#
# # 5. What do you want to learn next in CompSci?
#
# - I want to learn how to make a website secure, and also test insecurities through cybersecurity.
#
# # 6. Analytics Review
#
# - my analytics:
#
# ![Tri 1 Analytics]({{site.baseurl}}/images/tri1analytics.png)
#
# # 7. AP CSA MC Review
# ![Tri 1 CSA MC Review]({{site.baseurl}}/images/mcscoretri1.png)
# ![Tri 1 CSA MC Breakdown]({{site.baseurl}}/images/tri1mcbreakdown.png)
#
# ## Revisions
# ### Q8:
# ![Question 8]({{site.baseurl}}/images/tri1question8.png)
# - Correction: Answer C is correct because the expression (int) w / x first casts w to the int 2 and then divides the result by the double 5.0. When an int is divided by a double, the int is automatically widened to a double, so the expression is calculated as 2.0 / 5.0, which evaluates to 0.4. The expression (int) (w / x) first divides w by x, which evaluates to 0.4. This result is then cast to an int, which evaluates to 0. This value is then automatically widened to 0.0 when it is assigned to the double variable z.
#
#
# ### Q14:
# ![Question 14]({{site.baseurl}}/images/tri1question14.png)
# - Correction: The answer is option A, By De Morgan’s law, !(isEven && isPositive) is equivalent to !isEven || !isPositive. The entire expression is equivalent to (!isEven || !isPositive) && isPrime.
#
# ### Q15:
# ![Question 15]({{site.baseurl}}/images/tri1question15.png)
# - Correction: Option A, the code segment repeatedly sets j to the index of the next occurrence of the target "o" in the string str. Each time an occurrence of "o" is found, the code segment prints the substring starting with that "o", then updates str to be the substring starting immediately after the "o". This is repeated until there are no "o"s remaining in str.
#
# ### Q17
# ![Question 17]({{site.baseurl}}/images/tri1question17.png)
# - Correction: Option B because system reliability is the ability for a program to perform its tasks as expected under stated conditions without failure. One way to maximize system reliability is to thoroughly test a program under many different possible conditions.
#
# ### Q19
# ![Question 19]({{site.baseurl}}/images/tri1question19.png)
# - Correction: Option C, the call Math.random() returns a double greater than or equal to 0.0 and less than 1.0. This value is multiplied by 6 to give a double greater than or equal to 0.0 and less than 6.0. Casting this to an int gives an integer between 0 and 5, inclusive. Adding 10 gives an integer between 10 and 15, inclusive.
#
# ### Q21
# ![Question 21]({{site.baseurl}}/images/tri1question21.png)
# - Correction: Option B is correct. The outer loop counts from j = 0 up to j = 3, incrementing by 1. To produce the given output, the inner loop should count up from k = 0 to k = j. This will cause one value to be printed in the first iteration of the outer loop, two values to be printed in the second iteration of the outer loop, and so on.
#
#
# ### Q22
# ![Question 22]({{site.baseurl}}/images/tri1question22.png)
# - Correction: Option D is correct; Correct. The variables pName and pSpecies are parameters in the Pet constructor and are local to the body of the constructor. They cannot be accessed elsewhere in the class.
#
# ### Q25
# ![Question 25]({{site.baseurl}}/images/tri1question25.png)
# - Correction: I said that 0 would be printed, but the answer is 2. The variable count is a static variable, which means it is shared among all Shoe objects. The value of count is initially 0. It is incremented by 1 in the two-parameter constructor, but not the no-parameter constructor. There are two calls to the two-parameter constructor, so count will be 2 as a result of executing the code segment.
#
# ### Q29
# ![Question 29]({{site.baseurl}}/images/tri1question29.png)
# - Correction: Option A, Correct. After calling printNums(10), n is less than 50, so printNums(-20) is called. At this point, n is still less than 50, so printNums(40) is called. At this point, n is still less than 50, so printNums(-80) is called. At this point, n is still less than 50, so printNums(160) is called. At this point, n is not less than 50, so there are no more recursive calls. Working backward from the last call, the values of n are printed in the order -80, 40, -20, and 10.
#
# ### Q32
# ![Question 32]({{site.baseurl}}/images/tri1question32.png)
# - Correction: Option B, The outer loop header traverses the rows from row 0 to row 1. The inner loop header traverses the columns from column 2 to column 0. The array elements are added to the ArrayList result as they accessed from right-to-left and from top-to-bottom.
#
# ### Q33
# ![Question 33]({{site.baseurl}}/images/tri1question33.png)
# - Correction: Option B, the code segment traverses the array from right to left starting at the last element and decrementing the index by 2 for each iteration of the loop. The value of each accessed element is incremented by 1.
#
# ### Q34
# ![Question 34]({{site.baseurl}}/images/tri1question34.png)
# - Correction: option B's code segment traverses oldList. For each iteration of the loop, it appends an element from oldList to the end of newList and inserts the same element at the beginning of newList.
#
# ### Q37
# ![Question 37]({{site.baseurl}}/images/tri1question37.png)
# - Correction: D, in the loop header, values[x] is row x in the two-dimensional array values. The loop traverses that row and increments the counter result each time an element is equal to target.
#
# ### Q38
# ![Question 38]({{site.baseurl}}/images/tri1question38.png)
# - Correction: C. For every string encountered in the file, the code segment will use the split method to place the text before the underscore in temp[0] and the text after the underscore in temp[1]. The value of temp[0] is added to firstList and the value of temp[1] is added to secondList.
#
# ### Q40
# ![Question 40]({{site.baseurl}}/images/tri1question40.png)
# - Correction: B. In each iteration of the outer loop, the method moves the element at index j to its proper position in the part of the list from index 0 to index j. After the first iteration of the outer loop, 30 is moved to index 0 so that the contents of numList are [30, 60, 10, 20, 50, 40]. After the second iteration of the outer loop, 10 is moved to index 0 so that the contents of numList are [10, 30, 60, 20, 50, 40]. After the third iteration of the outer loop, 20 is moved to index 1 so that the contents of numList are [10, 20, 30, 60, 50, 40].
#
# ### Q41
# ![Question 41]({{site.baseurl}}/images/tri1question41.png)
# - Correction: D, The code segment compares each string element in the array colors with each subsequent string element in the array. If the two strings are the same length, result is assigned k, the index of the string that appears later in the array. As the array is traversed, the last two elements found that have the same length are "black" and "brown". The later of these two elements is "brown", whose index is 5.
#
# ### Q42
# ![Question 42]({{site.baseurl}}/images/tri1question42.png)
# - Correction: Option D. The given while loop calculates the sum of the integers from 1 to 6. It iterates six times (from j = 0 to j = 5), and increments j just before adding it to sum. This for loop also calculates the sum of the integers from 1 to 6. It iterates six times (from j = 1 to j = 6), adding each value to sum.
#
#
# # Something Cool I'd like to Share
